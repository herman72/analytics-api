# %%
import requests
from pprint import pprint
path = "/api/events"
base_url = "http://localhost:8002" # 127.0.0.1
endpoint = f"{base_url}{path}"
endpoint
# Out:
# 'http://localhost:8002/api/events'

# %%
response = requests.get(endpoint, params={'duration': '1 week"'})
print('ok', response.ok)
if response.ok:
    data = response.json()
    pprint(data)
# Out:
# ok True
# [{'avg_duration': 2520.1238938053098,
#   'bucket': '2025-03-31T00:00:00Z',
#   'count': 113,
#   'operating_system': 'Android',
#   'page': '/',
#   'ua': ''},
#  {'avg_duration': 2347.7252747252746,
#   'bucket': '2025-03-31T00:00:00Z',
#   'count': 91,
#   'operating_system': 'Android',
#   'page': '/about',
#   'ua': ''},
#  {'avg_duration': 2442.8571428571427,
#   'bucket': '2025-03-31T00:00:00Z',
#   'count': 84,
#   'operating_system': 'Android',
#   'page': '/blog',
#   'ua': ''},
#  {'avg_duration': 2428.747474747475,
#   'bucket': '2025-03-31T00:00:00Z',
#   'count': 99,
#   'operating_system': 'Android',
#   'page': '/contact',
#   'ua': ''},
#  {'avg_duration': 2755.3039215686276,
#   'bucket': '2025-03-31T00:00:00Z',
#   'count': 102,
#   'operating_system': 'Android',
#   'page': '/dashboard',
#   'ua': ''},
#  {'avg_duration': 2635.2056074766356,
#   'bucket': '2025-03-31T00:00:00Z',
#   'count': 107,
#   'operating_system': 'Android',
#   'page': '/login',
#   'ua': ''},
#  {'avg_duration': 2669.9479166666665,
#   'bucket': '2025-03-31T00:00:00Z',
#   'count': 96,
#   'operating_system': 'Android',
#   'page': '/pricing',
#   'ua': ''},
#  {'avg_duration': 2497.7659574468084,
#   'bucket': '2025-03-31T00:00:00Z',
#   'count': 94,
#   'operating_system': 'Android',
#   'page': '/products',
#   'ua': ''},
#  {'avg_duration': 2569.1176470588234,
#   'bucket': '2025-03-31T00:00:00Z',
#   'count': 102,
#   'operating_system': 'Android',
#   'page': '/settings',
#   'ua': ''},
#  {'avg_duration': 2506.6153846153848,
#   'bucket': '2025-03-31T00:00:00Z',
#   'count': 91,
#   'operating_system': 'Android',
#   'page': '/signup',
#   'ua': ''},
#  {'avg_duration': 2481.5859030837005,
#   'bucket': '2025-03-31T00:00:00Z',
#   'count': 227,
#   'operating_system': 'Linux',
#   'page': '/',
#   'ua': ''},
#  {'avg_duration': 2609.480198019802,
#   'bucket': '2025-03-31T00:00:00Z',
#   'count': 202,
#   'operating_system': 'Linux',
#   'page': '/about',
#   'ua': ''},
#  {'avg_duration': 2413.355450236967,
#   'bucket': '2025-03-31T00:00:00Z',
#   'count': 211,
#   'operating_system': 'Linux',
#   'page': '/blog',
#   'ua': ''},
#  {'avg_duration': 2631.8711340206187,
#   'bucket': '2025-03-31T00:00:00Z',
#   'count': 194,
#   'operating_system': 'Linux',
#   'page': '/contact',
#   'ua': ''},
#  {'avg_duration': 2545.004739336493,
#   'bucket': '2025-03-31T00:00:00Z',
#   'count': 211,
#   'operating_system': 'Linux',
#   'page': '/dashboard',
#   'ua': ''},
#  {'avg_duration': 2624.7393162393164,
#   'bucket': '2025-03-31T00:00:00Z',
#   'count': 234,
#   'operating_system': 'Linux',
#   'page': '/login',
#   'ua': ''},
#  {'avg_duration': 2344.7557603686637,
#   'bucket': '2025-03-31T00:00:00Z',
#   'count': 217,
#   'operating_system': 'Linux',
#   'page': '/pricing',
#   'ua': ''},
#  {'avg_duration': 2352.455958549223,
#   'bucket': '2025-03-31T00:00:00Z',
#   'count': 193,
#   'operating_system': 'Linux',
#   'page': '/products',
#   'ua': ''},
#  {'avg_duration': 2526.208530805687,
#   'bucket': '2025-03-31T00:00:00Z',
#   'count': 211,
#   'operating_system': 'Linux',
#   'page': '/settings',
#   'ua': ''},
#  {'avg_duration': 2550.4304932735427,
#   'bucket': '2025-03-31T00:00:00Z',
#   'count': 223,
#   'operating_system': 'Linux',
#   'page': '/signup',
#   'ua': ''},
#  {'avg_duration': 2782.931818181818,
#   'bucket': '2025-03-31T00:00:00Z',
#   'count': 176,
#   'operating_system': 'MacOS',
#   'page': '/',
#   'ua': ''},
#  {'avg_duration': 2681.9190751445085,
#   'bucket': '2025-03-31T00:00:00Z',
#   'count': 173,
#   'operating_system': 'MacOS',
#   'page': '/about',
#   'ua': ''},
#  {'avg_duration': 2606.6060606060605,
#   'bucket': '2025-03-31T00:00:00Z',
#   'count': 165,
#   'operating_system': 'MacOS',
#   'page': '/blog',
#   'ua': ''},
#  {'avg_duration': 2560.1017964071857,
#   'bucket': '2025-03-31T00:00:00Z',
#   'count': 167,
#   'operating_system': 'MacOS',
#   'page': '/contact',
#   'ua': ''},
#  {'avg_duration': 2918.224043715847,
#   'bucket': '2025-03-31T00:00:00Z',
#   'count': 183,
#   'operating_system': 'MacOS',
#   'page': '/dashboard',
#   'ua': ''},
#  {'avg_duration': 2404.4745762711864,
#   'bucket': '2025-03-31T00:00:00Z',
#   'count': 177,
#   'operating_system': 'MacOS',
#   'page': '/login',
#   'ua': ''},
#  {'avg_duration': 2515.2285714285713,
#   'bucket': '2025-03-31T00:00:00Z',
#   'count': 175,
#   'operating_system': 'MacOS',
#   'page': '/pricing',
#   'ua': ''},
#  {'avg_duration': 2643.5597826086955,
#   'bucket': '2025-03-31T00:00:00Z',
#   'count': 184,
#   'operating_system': 'MacOS',
#   'page': '/products',
#   'ua': ''},
#  {'avg_duration': 2707.3097826086955,
#   'bucket': '2025-03-31T00:00:00Z',
#   'count': 184,
#   'operating_system': 'MacOS',
#   'page': '/settings',
#   'ua': ''},
#  {'avg_duration': 2486.6806282722514,
#   'bucket': '2025-03-31T00:00:00Z',
#   'count': 191,
#   'operating_system': 'MacOS',
#   'page': '/signup',
#   'ua': ''},
#  {'avg_duration': 2637.1,
#   'bucket': '2025-03-31T00:00:00Z',
#   'count': 50,
#   'operating_system': 'Other',
#   'page': '/',
#   'ua': ''},
#  {'avg_duration': 2536.0,
#   'bucket': '2025-03-31T00:00:00Z',
#   'count': 44,
#   'operating_system': 'Other',
#   'page': '/about',
#   'ua': ''},
#  {'avg_duration': 2290.5471698113206,
#   'bucket': '2025-03-31T00:00:00Z',
#   'count': 53,
#   'operating_system': 'Other',
#   'page': '/blog',
#   'ua': ''},
#  {'avg_duration': 2787.66,
#   'bucket': '2025-03-31T00:00:00Z',
#   'count': 50,
#   'operating_system': 'Other',
#   'page': '/contact',
#   'ua': ''},
#  {'avg_duration': 2732.7441860465115,
#   'bucket': '2025-03-31T00:00:00Z',
#   'count': 43,
#   'operating_system': 'Other',
#   'page': '/dashboard',
#   'ua': ''},
#  {'avg_duration': 2702.5348837209303,
#   'bucket': '2025-03-31T00:00:00Z',
#   'count': 43,
#   'operating_system': 'Other',
#   'page': '/login',
#   'ua': ''},
#  {'avg_duration': 2785.7758620689656,
#   'bucket': '2025-03-31T00:00:00Z',
#   'count': 58,
#   'operating_system': 'Other',
#   'page': '/pricing',
#   'ua': ''},
#  {'avg_duration': 2452.673076923077,
#   'bucket': '2025-03-31T00:00:00Z',
#   'count': 52,
#   'operating_system': 'Other',
#   'page': '/products',
#   'ua': ''},
#  {'avg_duration': 2549.12,
#   'bucket': '2025-03-31T00:00:00Z',
#   'count': 50,
#   'operating_system': 'Other',
#   'page': '/settings',
#   'ua': ''},
#  {'avg_duration': 2450.101694915254,
#   'bucket': '2025-03-31T00:00:00Z',
#   'count': 59,
#   'operating_system': 'Other',
#   'page': '/signup',
#   'ua': ''},
#  {'avg_duration': 2377.6170212765956,
#   'bucket': '2025-03-31T00:00:00Z',
#   'count': 329,
#   'operating_system': 'Windows',
#   'page': '/',
#   'ua': ''},
#  {'avg_duration': 2466.588785046729,
#   'bucket': '2025-03-31T00:00:00Z',
#   'count': 321,
#   'operating_system': 'Windows',
#   'page': '/about',
#   'ua': ''},
#  {'avg_duration': 2493.407514450867,
#   'bucket': '2025-03-31T00:00:00Z',
#   'count': 346,
#   'operating_system': 'Windows',
#   'page': '/blog',
#   'ua': ''},
#  {'avg_duration': 2578.9003322259136,
#   'bucket': '2025-03-31T00:00:00Z',
#   'count': 301,
#   'operating_system': 'Windows',
#   'page': '/contact',
#   'ua': ''},
#  {'avg_duration': 2462.325513196481,
#   'bucket': '2025-03-31T00:00:00Z',
#   'count': 341,
#   'operating_system': 'Windows',
#   'page': '/dashboard',
#   'ua': ''},
#  {'avg_duration': 2604.558073654391,
#   'bucket': '2025-03-31T00:00:00Z',
#   'count': 353,
#   'operating_system': 'Windows',
#   'page': '/login',
#   'ua': ''},
#  {'avg_duration': 2531.923333333333,
#   'bucket': '2025-03-31T00:00:00Z',
#   'count': 300,
#   'operating_system': 'Windows',
#   'page': '/pricing',
#   'ua': ''},
#  {'avg_duration': 2565.0202898550724,
#   'bucket': '2025-03-31T00:00:00Z',
#   'count': 345,
#   'operating_system': 'Windows',
#   'page': '/products',
#   'ua': ''},
#  {'avg_duration': 2480.680216802168,
#   'bucket': '2025-03-31T00:00:00Z',
#   'count': 369,
#   'operating_system': 'Windows',
#   'page': '/settings',
#   'ua': ''},
#  {'avg_duration': 2486.8006230529595,
#   'bucket': '2025-03-31T00:00:00Z',
#   'count': 321,
#   'operating_system': 'Windows',
#   'page': '/signup',
#   'ua': ''},
#  {'avg_duration': 2428.659574468085,
#   'bucket': '2025-03-31T00:00:00Z',
#   'count': 141,
#   'operating_system': 'iOS',
#   'page': '/',
#   'ua': ''},
#  {'avg_duration': 2246.5535714285716,
#   'bucket': '2025-03-31T00:00:00Z',
#   'count': 112,
#   'operating_system': 'iOS',
#   'page': '/about',
#   'ua': ''},
#  {'avg_duration': 2485.8230088495575,
#   'bucket': '2025-03-31T00:00:00Z',
#   'count': 113,
#   'operating_system': 'iOS',
#   'page': '/blog',
#   'ua': ''},
#  {'avg_duration': 2575.292857142857,
#   'bucket': '2025-03-31T00:00:00Z',
#   'count': 140,
#   'operating_system': 'iOS',
#   'page': '/contact',
#   'ua': ''},
#  {'avg_duration': 2713.4418604651164,
#   'bucket': '2025-03-31T00:00:00Z',
#   'count': 129,
#   'operating_system': 'iOS',
#   'page': '/dashboard',
#   'ua': ''},
#  {'avg_duration': 2336.958620689655,
#   'bucket': '2025-03-31T00:00:00Z',
#   'count': 145,
#   'operating_system': 'iOS',
#   'page': '/login',
#   'ua': ''},
#  {'avg_duration': 2496.753846153846,
#   'bucket': '2025-03-31T00:00:00Z',
#   'count': 130,
#   'operating_system': 'iOS',
#   'page': '/pricing',
#   'ua': ''},
#  {'avg_duration': 2675.374045801527,
#   'bucket': '2025-03-31T00:00:00Z',
#   'count': 131,
#   'operating_system': 'iOS',
#   'page': '/products',
#   'ua': ''},
#  {'avg_duration': 2590.9333333333334,
#   'bucket': '2025-03-31T00:00:00Z',
#   'count': 120,
#   'operating_system': 'iOS',
#   'page': '/settings',
#   'ua': ''},
#  {'avg_duration': 2403.6641791044776,
#   'bucket': '2025-03-31T00:00:00Z',
#   'count': 134,
#   'operating_system': 'iOS',
#   'page': '/signup',
#   'ua': ''}]

# %%
if response.ok:
    data = response.json()
    print(data, type(data), data.get("item"))

# %%
detail_path = "/api/events/10"
detail_endpoint = f"{base_url}{detail_path}"
r = requests.get(detail_endpoint)
print('ok', r.status_code)
if r.ok:
    data = r.json()
    print(data)
# Out:
# ok 200
# {'updated_at': '2025-04-02T21:55:46.858154Z', 'id': 10, 'page': '/contact', 'time': '2025-04-02T21:55:46.858151Z', 'description': ''}
